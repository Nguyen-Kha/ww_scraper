# %%
# Setup Initial stuff

import spacy
import pymongo
from pymongo import MongoClient

nlp = spacy.load('en_core_web_sm')

client = MongoClient('mongodb://localhost:27017/WW?retryWrites=true&w=majority')
db = client['WW_Local']
NLP_jobs_collection = db['NLPJobsLocal']

# %%
# Testing spacy connection

doc = nlp("Apple is looking at buying U.K. startup - for $1 billion")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP compound X.X. False False
# startup startup NOUN NN dobj xxxx True False
# - - PUNCT HYPH punct - False False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
# Part of Speech Tagging
print((NLP_jobs_collection.find_one({}))['skills'] + '\n')
x = nlp((NLP_jobs_collection.find_one({}))['skills'])
for word in x:
    print(word.text, word.lemma_, word.pos_, word.tag_, word.dep_,
            word.shape_, word.is_alpha, word.is_stop)
# Out:
# What you bring to the table: - Confidence: A willingness to take on new challenges, and see them through to completion. - Humility: Mustn't be afraid to ask "stupid" questions and make mistakes (as long as you learn from them). - Curiosity: You look for better ways of doing things even if everyone seems happy with how things work right now. - Teamwork: Lone wolves, divas, and rockstars need not apply. We work together.  What you might have up your sleeves (not required): - Experience writing a macOS or iOS app, in Swift (or SwiftUI!) - An appreciation for the necessity of Accessibility in software. - Experience with Objective-C - Knowledge of XCTest, and writing test cases. - Familiarity with Rust. - Personal experience using 1Password (or other password managers).
#
# What what PRON WP dobj Xxxx True True
# you you PRON PRP nsubj xxx True True
# bring bring VERB VBP advcl xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# ...

# %%
# Named Entity Recognition
print((NLP_jobs_collection.find_one({}))['responsibilities'] + '\n')
x = nlp((NLP_jobs_collection.find_one({}))['responsibilities'])
for word in x.ents:
    print(word.text, word.start_char, word.end_char, word.label_)
# Out:
# - Implement or improve features in 1Password for macOS and/or iOS. - Create new, or improve existing, tooling to make the 1Password development process more robust. - Help us improve the overall quality of 1Password for its millions of users by developing new methods to automate testing and detect regressions before they make it to production. - Work on exciting projects that we haven't even thought up yet!
#
# 1Password 35 44 CARDINAL
# 1Password 122 131 CARDINAL
# 1Password 206 215 CARDINAL
# millions 224 232 CARDINAL
